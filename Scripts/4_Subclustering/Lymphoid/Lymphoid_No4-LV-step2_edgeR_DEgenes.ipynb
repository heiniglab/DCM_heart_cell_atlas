# %%
library(edgeR)
library(magrittr)
library(ggplot2)
library(DESeq2)
library(tidyverse)
# Out:
# Loading required package: limma
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.0.6     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()        masks IRanges::collapse()
# ✖ dplyr::combine()         masks Biobase::combine(), BiocGenerics::combine()
# ✖ dplyr::count()           masks matrixStats::count()
# ✖ dplyr::desc()            masks IRanges::desc()
# ✖ tidyr::expand()          masks S4Vectors::expand()
# ✖ tidyr::extract()         masks magrittr::extract()
# ✖ dplyr::filter()          masks stats::filter()
# ✖ dplyr::first()           masks S4Vectors::first()
# ✖ dplyr::lag()             masks stats::lag()
# ✖ BiocGenerics::Position() masks ggplot2::Position(), base::Position()
# ✖ purrr::reduce()          masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()          masks S4Vectors::rename()
# ✖ purrr::set_names()       masks magrittr::set_names()
# ✖ dplyr::slice()           masks IRanges::slice()

# %% [markdown]
# ## Automatise

# %%
path_csvs = '/home/jovyan/projects/kk14_DCM-lymphoid/results/for_edgeR/210526/'
path_csvs
# Out:
# [1] "/home/jovyan/projects/kk14_DCM-lymphoid/results/for_edgeR/210526/"

# %%
x=read.csv(paste0(path_csvs, "ALL_CELLSTATE_PSEUDOBULK_LVS.csv"), row.names=1, check.names=FALSE)
genes_tofilter=read.csv(paste0(path_csvs, "ALL_CELLSTATE_PSEUDOBULK_FILTERING_LVS.csv"), check.names=FALSE)
colnames(genes_tofilter) <- gsub("mutation.negative", 'PVneg', colnames(genes_tofilter))
colnames(genes_tofilter)[1]='X' # since check.names=FALSE remove 'X' from the first column name

# Only needed for the column cell_state
CELLTYPE_STATE <- read.csv(paste0(path_csvs, "CELLSTATE_TRANSLATION_TABLE.csv"))
colnames(CELLTYPE_STATE) <- c("cell_states", 'cell_type')

# Removes patients with only few (<10) nuclei numbers (as they might bias the analysis)
CELLTYPE_FILTER <- read.csv(paste0(path_csvs, "ABSOLUTE_CELLSTATES_NUMBER_LVS.csv"))

l <- strsplit(colnames(x), "__")

# %%
head(genes_tofilter)
# Out:
#   X           control_SMC1.2 control_vCM2 control_vCM1.0 control_EC8.0
# 1 MIR1302-2HG 0.000000000    7.728137e-05 2.363061e-05   0.00000000
# 2 FAM138A     0.000000000    4.704111e-05 0.000000e+00   0.00000000
# 3 OR4F5       0.000000000    0.000000e+00 0.000000e+00   0.00000000
# 4 AL627309.1  0.006045433    3.766473e-02 2.115259e-02   0.01851852
# 5 AL627309.3  0.000000000    0.000000e+00 0.000000e+00   0.00000000
# 6 AL627309.2  0.000000000    2.821294e-05 2.547252e-05   0.00000000
#   control_PC1  control_vCM3.0 control_PC3 control_NC2 control_vFB1.0 ⋯
# 1 0.000000e+00 0.000208686    0.000000000 0.00000000  0.0001331824   ⋯
# 2 0.000000e+00 0.000000000    0.000000000 0.00000000  0.0000000000   ⋯
# 3 0.000000e+00 0.000000000    0.000000000 0.00000000  0.0000000000   ⋯
# 4 5.671691e-03 0.026385827    0.006668741 0.05133929  0.0113499835   ⋯
# 5 0.000000e+00 0.000000000    0.000000000 0.00000000  0.0000000000   ⋯
# 6 1.529613e-05 0.000000000    0.000000000 0.00000000  0.0001032631   ⋯
#   PVneg_Meso PVneg_NC6 PVneg_NC1.3 PVneg_CD4T_reg PVneg_NK_CD16hiIFNGhi
# 1 0          0         0.00000000  0.00000000     0
# 2 0          0         0.00000000  0.00000000     0
# 3 0          0         0.00000000  0.00000000     0
# 4 0          0         0.04761905  0.08333334     0
# 5 0          0         0.00000000  0.00000000     0
# 6 0          0         0.00000000  0.00000000     0
#   PVneg_CD8T_te_IFNGhi PVneg_unclassified.2 PVneg_AD1.1 PVneg_unclassified.1
# 1 0.000000000          0                    0.0000000   0
# 2 0.000000000          0                    0.0000000   0
# 3 0.000000000          0                    0.0000000   0
# 4 0.006666666          0                    0.1111111   0
# 5 0.000000000          0                    0.0000000   0
# 6 0.000000000          0                    0.0000000   0
#   PVneg_AD3
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
CELLTYPE_STATE %>% filter(cell_type=='Lymphoid')
# Out:
#    cell_states      cell_type
# 1  CD4T_act         Lymphoid
# 2  Plasma           Lymphoid
# 3  CD8T_em          Lymphoid
# 4  CD8T_trans       Lymphoid
# 5  CD8T_te          Lymphoid
# 6  MAIT-like        Lymphoid
# 7  CD4T_naive       Lymphoid
# 8  NK_CD56hi        Lymphoid
# 9  NK_CD16hi        Lymphoid
# 10 ILC              Lymphoid
# 11 prolif_Lymphoids Lymphoid
# 12 B                Lymphoid
# 13 CD8T_cytox       Lymphoid
# 14 CD4T_reg         Lymphoid
# 15 NK_CD16hiIFNGhi  Lymphoid
# 16 CD8T_te_IFNGhi   Lymphoid
# 17 unclassified.2   Lymphoid
# 18 unclassified.1   Lymphoid

# %%
meta.data <- t(as.data.frame(l))
rownames(meta.data) <- colnames(x)

meta.data <- as.data.frame(meta.data)
colnames(meta.data)  <-  c("Genotype", "cell_state", 'Patient', 'X10X_version', 'Gender')

head(meta.data)
# Out:
#                         Genotype cell_state Patient X10X_version Gender
# LMNA__AD1.0__DL2__V3__m LMNA     AD1.0      DL2     V3           m
# LMNA__AD1.0__H05__V3__m LMNA     AD1.0      H05     V3           m
# LMNA__AD1.0__H26__V3__f LMNA     AD1.0      H26     V3           f
# LMNA__AD1.0__H28__V3__m LMNA     AD1.0      H28     V3           m
# LMNA__AD1.0__H31__V3__m LMNA     AD1.0      H31     V3           m
# LMNA__AD1.1__H05__V3__m LMNA     AD1.1      H05     V3           m

# %%
GENOTYPES <- unique(meta.data$Genotype)[-6]
GENOTYPES
# Out:
# [1] "LMNA"  "PKP2"  "PVneg" "RBM20" "TTN"

# %%
CELL_LEVEL <- "CELLSTATE"
REGION <- "LV"

# %%
CELLTYPE_FILTER_SUB <- CELLTYPE_FILTER
CELLTYPE_FILTER_SUB[,2:ncol(CELLTYPE_FILTER_SUB)] <- apply(CELLTYPE_FILTER_SUB[,-1], 2, function(i) i>5)

# %%
as.character(GENOTYPES)
# Out:
# [1] "LMNA"  "PKP2"  "PVneg" "RBM20" "TTN"

# %%
as.character(unique(meta.data$cell_state))
# Out:
#  [1] "AD1.0"            "AD1.1"            "AD2"              "B"
#  [5] "CD16+ Mo"         "CD4T_act"         "CD4T_naive"       "CD4T_reg"
#  [9] "CD8T_cytox"       "CD8T_em"          "CD8T_te_IFNGhi"   "CD8T_te"
# [13] "CD8T_trans"       "EC1.0"            "EC2.0"            "EC5.0"
# [17] "EC6.0"            "EC7.0"            "EC8.0"            "ILC"
# [21] "MAIT-like"        "MY10"             "MY12"             "MY14"
# [25] "MY15"             "MY16"             "MY1"              "MY2"
# [29] "MY3"              "MY4"              "MY5"              "MY7"
# [33] "MY8"              "MY9"              "Mast"             "Meso"
# [37] "NC1.0"            "NC1.1"            "NC1.2"            "NC1.3"
# [41] "NC1.4"            "NC1.5"            "NC2"              "NC3"
# [45] "NC4"              "NC5"              "NC6"              "NK_CD16hiIFNGhi"
# [49] "NK_CD16hi"        "NK_CD56hi"        "PC1"              "PC2"
# [53] "PC3"              "Plasma"           "SMC1.1"           "SMC1.2"
# [57] "SMC2"             "cDC1"             "cDC2"             "prolif Myeloids"
# [61] "prolif_Lymphoids" "unclassified.1"   "unclassified.2"   "vCM1.0"
# [65] "vCM1.1"           "vCM1.2"           "vCM1.3"           "vCM2"
# [69] "vCM3.0"           "vCM3.1"           "vCM4"             "vCM5"
# [73] "vFB1.0"           "vFB1.1"           "vFB1.2"           "vFB2"
# [77] "vFB3"             "vFB4"             "AD3"

# %%
i <- 1

for(GENOTYPE in as.character(GENOTYPES)){
    message("\n###START: ", GENOTYPE," #####\n")
    for(CELL_STATE in as.character(unique(meta.data$cell_state))){
        
        CONTROL_COLUMN <- paste("control_",CELL_STATE, sep="")
        GENOTYPE_COLUMN <- paste(GENOTYPE,"_", CELL_STATE, sep="")
        CELLTYPE <- as.character(CELLTYPE_STATE[which(CELLTYPE_STATE$cell_states==CELL_STATE),"cell_type"])
        
        
        x_sub <- x[,which(meta.data$Genotype %in% c("control", GENOTYPE))]
        meta.data_sub <- meta.data[which(meta.data$Genotype %in% c("control", GENOTYPE)),]
        
        x_sub <- x_sub[,which(meta.data_sub$cell_state %in% c(CELL_STATE))]
        meta.data_sub <- meta.data_sub[which(meta.data_sub$cell_state %in% c(CELL_STATE)),]
        
        # Suggestion: Remove samples with less than 5 nuclei 
        PATIENTS_TOKEEP <- CELLTYPE_FILTER_SUB[which(CELLTYPE_FILTER_SUB$cell_states==CELL_STATE),-1]
        PATIENTS_TOKEEP <- colnames(PATIENTS_TOKEEP)[which(as.logical(PATIENTS_TOKEEP))]
        x_sub <- x_sub[,which(meta.data_sub$Patient %in% PATIENTS_TOKEEP)]
        meta.data_sub <- meta.data_sub[which(meta.data_sub$Patient %in% PATIENTS_TOKEEP),]
        
        # The test is only run, if 2 conditions have at least 2 patients
        if (length(unique(meta.data_sub$Genotype))==2 &
           all(table(meta.data_sub$Genotype)>2)
           ){
             # Prepare DGEList object
            meta.data_sub$Genotype <- as.factor(as.character(meta.data_sub$Genotype))
            dge <- DGEList(counts=x_sub, group=meta.data_sub$Genotype)
            
            # Filter genes based on expression, the qlf Object will be filtered to exclude them from FDR calculation
            keep <- genes_tofilter[,CONTROL_COLUMN]>0.0125 | ##### change & to | ##### 
                    genes_tofilter[,GENOTYPE_COLUMN]>0.0125
            #dge <- dge[keep, , keep.lib.sizes=FALSE]
    
            # PP, model matrix, https://www.nature.com/articles/nmeth.4612 (edgeRQLFDetRate)
            dge <- calcNormFactors(dge)
            cdr <- scale(colMeans(x_sub > 0))
            design <- model.matrix(~ cdr + meta.data_sub$Genotype)
    
            # 
            dge <- estimateDisp(dge, design = design)
            fit <- glmQLFit(dge, design = design)
            qlf <- glmQLFTest(fit)
    
            # For all
            tt <- topTags(qlf, n = Inf)
            
            # Only for "expressed/detected" genes
            tt_filtered <- topTags(qlf[keep,], n = Inf)
            
            tt$table[,"Gene"] <- as.character(rownames(tt$table))
            tt_filtered$table[,"Gene"] <- as.character(rownames(tt_filtered$table))
            tt_filtered$table[,"low_expression"] <- "F" #####  Low-expression column ##### 
            tt_filtered$table[,"FDR_plot"] <- -log10(tt_filtered$table$FDR) #####  For plotting Volcano, here we use FDR, not pValue  ##### 
            
            
            tt_merged <- merge(tt$table[,c("Gene", "logFC", "logCPM", 'F', 'PValue')], 
                               tt_filtered$table[,c("Gene", "FDR", "low_expression", "FDR_plot")], 
                               by="Gene", all=T)   
            
            # Replace NA FDRs with NA                   #####  ORDER CHANGED #####  
            tt_merged[which(is.na(tt_merged$FDR)),"FDR"] <- 1 
            
            EXPRESSION_MEAN <- genes_tofilter[,c("X", CONTROL_COLUMN, GENOTYPE_COLUMN)]
            colnames(EXPRESSION_MEAN) <- c("Gene", "mean_exp_control", 'mean_exp_genotype')
            tt_merged <- merge(tt_merged, EXPRESSION_MEAN, by="Gene")
    
            
            tt_merged[,"Region"] <- REGION
            tt_merged[,"annotation_level"] <- CELL_LEVEL
            tt_merged[,"cell_state"] <- CELL_STATE
            tt_merged[,"cell_type"] <- CELLTYPE
            tt_merged[,"comparison"] <- paste("control_", GENOTYPE, sep="")
            
            if(i==1){
                 final_df <- tt_merged   
            } else {
                final_df <- rbind(final_df, tt_merged)
            }
            
            i <- i + 1
            message("\n###FINISHED: ", CELL_STATE," #####\n")
        }
    }
}
# Out:
# ###START: LMNA #####
#
#
#
# ###FINISHED: AD1.1 #####
#
#
#
# ###FINISHED: AD2 #####
#
#
#
# ###FINISHED: CD16+ Mo #####
#
#
#
# ###FINISHED: CD4T_act #####
#
#
#
# ###FINISHED: CD4T_naive #####
#
#
#
# ###FINISHED: CD8T_cytox #####
#
#
#
# ###FINISHED: CD8T_em #####
#
#
#
# ###FINISHED: CD8T_te #####
#
#
#
# ###FINISHED: CD8T_trans #####
#
#
#
# ###FINISHED: EC1.0 #####
#
#
#
# ###FINISHED: EC2.0 #####
#
#
#
# ###FINISHED: EC5.0 #####
#
#
#
# ###FINISHED: EC6.0 #####
#
#
#
# ###FINISHED: EC7.0 #####
#
#
#
# ###FINISHED: EC8.0 #####
#
#
#
# ###FINISHED: MAIT-like #####
#
#
#
# ###FINISHED: MY10 #####
#
#
#
# ###FINISHED: MY12 #####
#
#
#
# ###FINISHED: MY14 #####
#
#
#
# ###FINISHED: MY16 #####
#
#
#
# ###FINISHED: MY1 #####
#
#
#
# ###FINISHED: MY2 #####
#
#
#
# ###FINISHED: MY3 #####
#
#
#
# ###FINISHED: MY4 #####
#
#
#
# ###FINISHED: MY5 #####
#
#
#
# ###FINISHED: MY7 #####
#
#
#
# ###FINISHED: MY8 #####
#
#
#
# ###FINISHED: MY9 #####
#
#
#
# ###FINISHED: Mast #####
#
#
#
# ###FINISHED: NC1.0 #####
#
#
#
# ###FINISHED: NC1.1 #####
#
#
#
# ###FINISHED: NC1.4 #####
#
#
#
# ###FINISHED: NC2 #####
#
#
#
# ###FINISHED: NK_CD16hi #####
#
#
#
# ###FINISHED: NK_CD56hi #####
#
#
#
# ###FINISHED: PC1 #####
#
#
#
# ###FINISHED: PC2 #####
#
#
#
# ###FINISHED: PC3 #####
#
#
#
# ###FINISHED: SMC1.1 #####
#
#
#
# ###FINISHED: SMC1.2 #####
#
#
#
# ###FINISHED: SMC2 #####
#
#
#
# ###FINISHED: cDC2 #####
#
#
#
# ###FINISHED: prolif Myeloids #####
#
#
#
# ###FINISHED: vCM1.0 #####
#
#
#
# ###FINISHED: vCM1.1 #####
#
#
#
# ###FINISHED: vCM1.2 #####
#
#
#
# ###FINISHED: vCM1.3 #####
#
#
#
# ###FINISHED: vCM2 #####
#
#
#
# ###FINISHED: vCM3.0 #####
#
#
#
# ###FINISHED: vCM3.1 #####
#
#
#
# ###FINISHED: vCM4 #####
#
#
#
# ###FINISHED: vCM5 #####
#
#
#
# ###FINISHED: vFB1.0 #####
#
#
#
# ###FINISHED: vFB1.1 #####
#
#
#
# ###FINISHED: vFB1.2 #####
#
#
#
# ###FINISHED: vFB2 #####
#
#
#
# ###FINISHED: vFB3 #####
#
#
#
# ###FINISHED: vFB4 #####
#
#
#
# ###START: PKP2 #####
#
#
#
# ###FINISHED: AD1.1 #####
#
#
#
# ###FINISHED: CD16+ Mo #####
#
#
#
# ###FINISHED: CD4T_act #####
#
#
#
# ###FINISHED: CD4T_naive #####
#
#
#
# ###FINISHED: CD8T_cytox #####
#
#
#
# ###FINISHED: CD8T_em #####
#
#
#
# ###FINISHED: CD8T_te #####
#
#
#
# ###FINISHED: CD8T_trans #####
#
#
#
# ###FINISHED: EC1.0 #####
#
#
#
# ###FINISHED: EC2.0 #####
#
#
#
# ###FINISHED: EC5.0 #####
#
#
#
# ###FINISHED: EC6.0 #####
#
#
#
# ###FINISHED: EC7.0 #####
#
#
#
# ###FINISHED: EC8.0 #####
#
#
#
# ###FINISHED: MY10 #####
#
#
#
# ###FINISHED: MY12 #####
#
#
#
# ###FINISHED: MY14 #####
#
#
#
# ###FINISHED: MY16 #####
#
#
#
# ###FINISHED: MY1 #####
#
#
#
# ###FINISHED: MY2 #####
#
#
#
# ###FINISHED: MY3 #####
#
#
#
# ###FINISHED: MY4 #####
#
#
#
# ###FINISHED: MY5 #####
#
#
#
# ###FINISHED: MY7 #####
#
#
#
# ###FINISHED: MY8 #####
#
#
#
# ###FINISHED: MY9 #####
#
#
#
# ###FINISHED: Mast #####
#
#
#
# ###FINISHED: NC1.0 #####
#
#
#
# ###FINISHED: NC1.1 #####
#
#
#
# ###FINISHED: NC1.3 #####
#
#
#
# ###FINISHED: NC1.4 #####
#
#
#
# ###FINISHED: NC2 #####
#
#
#
# ###FINISHED: NC5 #####
#
#
#
# ###FINISHED: NK_CD16hi #####
#
#
#
# ###FINISHED: NK_CD56hi #####
#
#
#
# ###FINISHED: PC1 #####
#
#
#
# ###FINISHED: PC2 #####
#
#
#
# ###FINISHED: PC3 #####
#
#
#
# ###FINISHED: SMC1.1 #####
#
#
#
# ###FINISHED: SMC1.2 #####
#
#
#
# ###FINISHED: SMC2 #####
#
#
#
# ###FINISHED: cDC2 #####
#
#
#
# ###FINISHED: vCM1.0 #####
#
#
#
# ###FINISHED: vCM1.1 #####
#
#
#
# ###FINISHED: vCM1.2 #####
#
#
#
# ###FINISHED: vCM1.3 #####
#
#
#
# ###FINISHED: vCM2 #####
#
#
#
# ###FINISHED: vCM3.0 #####
#
#
#
# ###FINISHED: vCM3.1 #####
#
#
#
# ###FINISHED: vCM4 #####
#
#
#
# ###FINISHED: vCM5 #####
#
#
#
# ###FINISHED: vFB1.0 #####
#
#
#
# ###FINISHED: vFB1.1 #####
#
#
#
# ###FINISHED: vFB1.2 #####
#
#
#
# ###FINISHED: vFB2 #####
#
#
#
# ###FINISHED: vFB3 #####
#
#
#
# ###FINISHED: vFB4 #####
#
#
#
# ###START: PVneg #####
#
#
#
# ###FINISHED: CD16+ Mo #####
#
#
#
# ###FINISHED: CD4T_act #####
#
#
#
# ###FINISHED: CD4T_naive #####
#
#
#
# ###FINISHED: CD8T_cytox #####
#
#
#
# ###FINISHED: CD8T_em #####
#
#
#
# ###FINISHED: CD8T_te #####
#
#
#
# ###FINISHED: CD8T_trans #####
#
#
#
# ###FINISHED: EC1.0 #####
#
#
#
# ###FINISHED: EC2.0 #####
#
#
#
# ###FINISHED: EC5.0 #####
#
#
#
# ###FINISHED: EC6.0 #####
#
#
#
# ###FINISHED: EC7.0 #####
#
#
#
# ###FINISHED: EC8.0 #####
#
#
#
# ###FINISHED: MAIT-like #####
#
#
#
# ###FINISHED: MY10 #####
#
#
#
# ###FINISHED: MY12 #####
#
#
#
# ###FINISHED: MY15 #####
#
#
#
# ###FINISHED: MY1 #####
#
#
#
# ###FINISHED: MY2 #####
#
#
#
# ###FINISHED: MY3 #####
#
#
#
# ###FINISHED: MY4 #####
#
#
#
# ###FINISHED: MY5 #####
#
#
#
# ###FINISHED: MY7 #####
#
#
#
# ###FINISHED: MY8 #####
#
#
#
# ###FINISHED: MY9 #####
#
#
#
# ###FINISHED: NC1.0 #####
#
#
#
# ###FINISHED: NC1.1 #####
#
#
#
# ###FINISHED: NC1.4 #####
#
#
#
# ###FINISHED: NC2 #####
#
#
#
# ###FINISHED: NK_CD16hi #####
#
#
#
# ###FINISHED: NK_CD56hi #####
#
#
#
# ###FINISHED: PC1 #####
#
#
#
# ###FINISHED: PC2 #####
#
#
#
# ###FINISHED: PC3 #####
#
#
#
# ###FINISHED: SMC1.1 #####
#
#
#
# ###FINISHED: SMC1.2 #####
#
#
#
# ###FINISHED: SMC2 #####
#
#
#
# ###FINISHED: cDC2 #####
#
#
#
# ###FINISHED: prolif Myeloids #####
#
#
#
# ###FINISHED: vCM1.0 #####
#
#
#
# ###FINISHED: vCM1.1 #####
#
#
#
# ###FINISHED: vCM1.2 #####
#
#
#
# ###FINISHED: vCM1.3 #####
#
#
#
# ###FINISHED: vCM2 #####
#
#
#
# ###FINISHED: vCM3.0 #####
#
#
#
# ###FINISHED: vCM3.1 #####
#
#
#
# ###FINISHED: vCM4 #####
#
#
#
# ###FINISHED: vCM5 #####
#
#
#
# ###FINISHED: vFB1.0 #####
#
#
#
# ###FINISHED: vFB1.1 #####
#
#
#
# ###FINISHED: vFB1.2 #####
#
#
#
# ###FINISHED: vFB2 #####
#
#
#
# ###FINISHED: vFB3 #####
#
#
#
# ###FINISHED: vFB4 #####
#
#
#
# ###START: RBM20 #####
#
#
#
# ###FINISHED: CD16+ Mo #####
#
#
#
# ###FINISHED: CD4T_act #####
#
#
#
# ###FINISHED: CD4T_naive #####
#
#
#
# ###FINISHED: CD8T_em #####
#
#
#
# ###FINISHED: CD8T_te #####
#
#
#
# ###FINISHED: CD8T_trans #####
#
#
#
# ###FINISHED: EC1.0 #####
#
#
#
# ###FINISHED: EC2.0 #####
#
#
#
# ###FINISHED: EC5.0 #####
#
#
#
# ###FINISHED: EC6.0 #####
#
#
#
# ###FINISHED: EC7.0 #####
#
#
#
# ###FINISHED: EC8.0 #####
#
#
#
# ###FINISHED: MAIT-like #####
#
#
#
# ###FINISHED: MY10 #####
#
#
#
# ###FINISHED: MY12 #####
#
#
#
# ###FINISHED: MY1 #####
#
#
#
# ###FINISHED: MY2 #####
#
#
#
# ###FINISHED: MY3 #####
#
#
#
# ###FINISHED: MY4 #####
#
#
#
# ###FINISHED: MY5 #####
#
#
#
# ###FINISHED: MY7 #####
#
#
#
# ###FINISHED: MY8 #####
#
#
#
# ###FINISHED: MY9 #####
#
#
#
# ###FINISHED: Mast #####
#
#
#
# ###FINISHED: NC1.0 #####
#
#
#
# ###FINISHED: NC1.1 #####
#
#
#
# ###FINISHED: NC1.3 #####
#
#
#
# ###FINISHED: NC1.4 #####
#
#
#
# ###FINISHED: NC2 #####
#
#
#
# ###FINISHED: NC5 #####
#
#
#
# ###FINISHED: NK_CD16hi #####
#
#
#
# ###FINISHED: NK_CD56hi #####
#
#
#
# ###FINISHED: PC1 #####
#
#
#
# ###FINISHED: PC2 #####
#
#
#
# ###FINISHED: PC3 #####
#
#
#
# ###FINISHED: SMC1.1 #####
#
#
#
# ###FINISHED: SMC1.2 #####
#
#
#
# ###FINISHED: SMC2 #####
#
#
#
# ###FINISHED: cDC2 #####
#
#
#
# ###FINISHED: vCM1.0 #####
#
#
#
# ###FINISHED: vCM1.1 #####
#
#
#
# ###FINISHED: vCM1.2 #####
#
#
#
# ###FINISHED: vCM1.3 #####
#
#
#
# ###FINISHED: vCM2 #####
#
#
#
# ###FINISHED: vCM3.0 #####
#
#
#
# ###FINISHED: vCM3.1 #####
#
#
#
# ###FINISHED: vCM4 #####
#
#
#
# ###FINISHED: vCM5 #####
#
#
#
# ###FINISHED: vFB1.0 #####
#
#
#
# ###FINISHED: vFB1.1 #####
#
#
#
# ###FINISHED: vFB1.2 #####
#
#
#
# ###FINISHED: vFB2 #####
#
#
#
# ###FINISHED: vFB3 #####
#
#
#
# ###FINISHED: vFB4 #####
#
#
#
# ###START: TTN #####
#
#
#
# ###FINISHED: CD16+ Mo #####
#
#
#
# ###FINISHED: CD4T_act #####
#
#
#
# ###FINISHED: CD4T_naive #####
#
#
#
# ###FINISHED: CD8T_cytox #####
#
#
#
# ###FINISHED: CD8T_em #####
#
#
#
# ###FINISHED: CD8T_te #####
#
#
#
# ###FINISHED: CD8T_trans #####
#
#
#
# ###FINISHED: EC1.0 #####
#
#
#
# ###FINISHED: EC2.0 #####
#
#
#
# ###FINISHED: EC5.0 #####
#
#
#
# ###FINISHED: EC6.0 #####
#
#
#
# ###FINISHED: EC7.0 #####
#
#
#
# ###FINISHED: EC8.0 #####
#
#
#
# ###FINISHED: MAIT-like #####
#
#
#
# ###FINISHED: MY10 #####
#
#
#
# ###FINISHED: MY12 #####
#
#
#
# ###FINISHED: MY14 #####
#
#
#
# ###FINISHED: MY15 #####
#
#
#
# ###FINISHED: MY16 #####
#
#
#
# ###FINISHED: MY1 #####
#
#
#
# ###FINISHED: MY2 #####
#
#
#
# ###FINISHED: MY3 #####
#
#
#
# ###FINISHED: MY4 #####
#
#
#
# ###FINISHED: MY5 #####
#
#
#
# ###FINISHED: MY7 #####
#
#
#
# ###FINISHED: MY8 #####
#
#
#
# ###FINISHED: MY9 #####
#
#
#
# ###FINISHED: Mast #####
#
#
#
# ###FINISHED: NC1.0 #####
#
#
#
# ###FINISHED: NC1.1 #####
#
#
#
# ###FINISHED: NC1.4 #####
#
#
#
# ###FINISHED: NC2 #####
#
#
#
# ###FINISHED: NC5 #####
#
#
#
# ###FINISHED: NK_CD16hi #####
#
#
#
# ###FINISHED: NK_CD56hi #####
#
#
#
# ###FINISHED: PC1 #####
#
#
#
# ###FINISHED: PC2 #####
#
#
#
# ###FINISHED: PC3 #####
#
#
#
# ###FINISHED: SMC1.1 #####
#
#
#
# ###FINISHED: SMC1.2 #####
#
#
#
# ###FINISHED: SMC2 #####
#
#
#
# ###FINISHED: cDC2 #####
#
#
#
# ###FINISHED: prolif Myeloids #####
#
#
#
# ###FINISHED: vCM1.0 #####
#
#
#
# ###FINISHED: vCM1.1 #####
#
#
#
# ###FINISHED: vCM1.2 #####
#
#
#
# ###FINISHED: vCM1.3 #####
#
#
#
# ###FINISHED: vCM2 #####
#
#
#
# ###FINISHED: vCM3.0 #####
#
#
#
# ###FINISHED: vCM3.1 #####
#
#
#
# ###FINISHED: vCM4 #####
#
#
#
# ###FINISHED: vCM5 #####
#
#
#
# ###FINISHED: vFB1.0 #####
#
#
#
# ###FINISHED: vFB1.1 #####
#
#
#
# ###FINISHED: vFB1.2 #####
#
#
#
# ###FINISHED: vFB2 #####
#
#
#
# ###FINISHED: vFB3 #####
#
#
#
# ###FINISHED: vFB4 #####

# %%
meta.data_sub
# Out:
#                             Genotype cell_state Patient X10X_version Gender
# control__AD3__BS_H26__V3__m control  AD3        BS_H26  V3           m

# %%
head(final_df)
# Out:
#   Gene     logFC         logCPM   F            PValue     FDR low_expression
# 1 A1BG     -1.826956e+00 5.236298 4.925270e-01 0.48280344 1   F
# 2 A1BG-AS1  6.143446e-17 5.131525 0.000000e+00 1.00000000 1   NA
# 3 A1CF      1.884520e+00 5.213165 4.492726e-01 0.50268174 1   NA
# 4 A2M       3.659995e+00 5.564544 3.534719e+00 0.06009868 1   F
# 5 A2M-AS1  -1.415215e+00 5.217481 8.294089e-08 0.99977021 1   NA
# 6 A2ML1     6.143446e-17 5.131525 0.000000e+00 1.00000000 1   NA
#   FDR_plot mean_exp_control mean_exp_genotype Region annotation_level
# 1  0       0.01851852       0.00000000        LV     CELLSTATE
# 2 NA       0.00000000       0.00000000        LV     CELLSTATE
# 3 NA       0.00000000       0.00462963        LV     CELLSTATE
# 4  0       0.00000000       0.09722222        LV     CELLSTATE
# 5 NA       0.01111111       0.00000000        LV     CELLSTATE
# 6 NA       0.00000000       0.00000000        LV     CELLSTATE
#   cell_state cell_type comparison
# 1 AD1.1      AD        control_LMNA
# 2 AD1.1      AD        control_LMNA
# 3 AD1.1      AD        control_LMNA
# 4 AD1.1      AD        control_LMNA
# 5 AD1.1      AD        control_LMNA
# 6 AD1.1      AD        control_LMNA

# %%
tail(final_df)
# Out:
#         Gene   logFC      logCPM   F         PValue     FDR
# 9424173 ZXDB   -0.8793595 2.646900 2.3759966 0.12967598 1.0000000
# 9424174 ZXDC    0.1884164 6.614096 1.5478392 0.21940012 0.4574654
# 9424175 ZYG11A -0.1996221 2.986955 0.1418047 0.70812656 1.0000000
# 9424176 ZYG11B  0.2527605 6.283061 2.7807413 0.10181252 0.2921935
# 9424177 ZYX    -0.7261541 4.436926 5.3063500 0.02555078 0.1227531
# 9424178 ZZEF1   0.1289970 6.690831 0.7087126 0.40398010 0.6458588
#         low_expression FDR_plot  mean_exp_control mean_exp_genotype Region
# 9424173 NA                    NA 0.004488071      0.002088314       LV
# 9424174 F              0.3396418 0.181390450      0.269253460       LV
# 9424175 NA                    NA 0.010091202      0.005229333       LV
# 9424176 F              0.5343295 0.141435340      0.214863730       LV
# 9424177 F              0.9109676 0.041144000      0.037142362       LV
# 9424178 F              0.1898624 0.199194100      0.280689420       LV
#         annotation_level cell_state cell_type comparison
# 9424173 CELLSTATE        vFB4       FB        control_TTN
# 9424174 CELLSTATE        vFB4       FB        control_TTN
# 9424175 CELLSTATE        vFB4       FB        control_TTN
# 9424176 CELLSTATE        vFB4       FB        control_TTN
# 9424177 CELLSTATE        vFB4       FB        control_TTN
# 9424178 CELLSTATE        vFB4       FB        control_TTN

# %% [markdown]
# ## Subset lymphoid DEGs and save

# %%
final_df %>% pull(cell_type) %>% unique()
# Out:
# [1] "AD"       "Myeloid"  "Lymphoid" "EC"       "Mast"     "N"        "Mural"
# [8] "CM"       "FB"

# %%
lymphoid_df = final_df %>% filter(cell_type=='Lymphoid')
lymphoid_df
# Out:
#         Gene        logFC         logCPM    F            PValue      FDR
# 1       A1BG        -9.533713e-01  6.731763  1.28572414  0.306531924 1.0000000
# 2       A1BG-AS1     1.092857e+00  6.932621  1.77966407  0.182191148 0.8059838
# 3       A1CF         1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
# 4       A2M         -1.210069e+00  8.471538  8.07815776  0.004480366 0.4032423
# 5       A2M-AS1     -7.146986e-01  7.267749  1.16631962  0.280159238 0.8697359
# 6       A2ML1       -9.241492e-01  6.593884  2.85490748  0.249162452 1.0000000
# 7       A2ML1-AS1    1.925183e+00  6.634470  7.57024551  0.041318237 0.5972205
# 8       A2ML1-AS2    1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
# 9       A3GALT2      1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
# 10      A4GALT       4.912106e-01  6.665633  0.37792886  0.627032070 1.0000000
# 11      A4GNT        1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
# 12      AAAS        -7.920684e-01  6.753686  0.85448768  0.399341605 0.9157432
# 13      AACS        -3.618067e-01  6.971360  0.21178442  0.645372564 0.9812859
# 14      AADAC        1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
# 15      AADACL2      1.412016e-16  6.552405  0.00000000  1.000000000 1.0000000
#
CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 2       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 3       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 4       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 5       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 6       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 7       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 8       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 9       CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 10      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 11      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 12      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 13      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 14      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 15      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 16      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 17      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 18      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 19      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 20      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 21      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 22      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 23      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 24      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 25      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 26      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 27      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 28      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 29      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# 30      CELLSTATE        CD4T_act   Lymphoid  control_LMNA
# ⋮       ⋮                ⋮          ⋮         ⋮
# 1442105 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442106 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442107 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442108 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442109 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442110 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442111 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442112 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442113 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442114 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442115 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442116 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442117 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442118 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442119 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442120 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442121 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442122 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442123 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442124 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442125 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442126 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442127 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442128 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442129 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442130 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442131 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442132 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442133 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN
# 1442134 CELLSTATE        NK_CD56hi  Lymphoid  control_TTN

# %%
write.csv(lymphoid_df, file='/home/jovyan/projects/kk14_DCM-lymphoid/results/DEGs_df/210526/LYMPHOIDS_ALLGENOTYPES_EDGER_LV.csv')

# %%
lymphoid_df = read.csv('/home/jovyan/projects/kk14_DCM-lymphoid/results/DEGs_df/210526/LYMPHOIDS_ALLGENOTYPES_EDGER_LV.csv', header=TRUE, row.names=1)
head(lymphoid_df)
# Out:
#   Gene     logFC         logCPM   F        PValue      FDR       low_expression
# 1 A1BG     -9.533713e-01 6.731763 1.285724 0.306531924 1.0000000    NA
# 2 A1BG-AS1  1.092857e+00 6.932621 1.779664 0.182191148 0.8059838 FALSE
# 3 A1CF      1.412016e-16 6.552405 0.000000 1.000000000 1.0000000    NA
# 4 A2M      -1.210069e+00 8.471538 8.078158 0.004480366 0.4032423 FALSE
# 5 A2M-AS1  -7.146986e-01 7.267749 1.166320 0.280159238 0.8697359 FALSE
# 6 A2ML1    -9.241492e-01 6.593884 2.854907 0.249162452 1.0000000    NA
#   FDR_plot   mean_exp_control mean_exp_genotype Region annotation_level
# 1         NA 0.007598785      0.00479798        LV     CELLSTATE
# 2 0.09367371 0.008897485      0.04370100        LV     CELLSTATE
# 3         NA 0.000000000      0.00000000        LV     CELLSTATE
# 4 0.39443395 0.366576020      0.12160778        LV     CELLSTATE
# 5 0.06061261 0.062041476      0.03746966        LV     CELLSTATE
# 6         NA 0.006060606      0.00000000        LV     CELLSTATE
#   cell_state cell_type comparison
# 1 CD4T_act   Lymphoid  control_LMNA
# 2 CD4T_act   Lymphoid  control_LMNA
# 3 CD4T_act   Lymphoid  control_LMNA
# 4 CD4T_act   Lymphoid  control_LMNA
# 5 CD4T_act   Lymphoid  control_LMNA
# 6 CD4T_act   Lymphoid  control_LMNA

# %%
dim(lymphoid_df)
# Out:
# [1] 1442134      15

# %%
# Filter table to make list shorter
lymphoid_df_sel = lymphoid_df %>% filter(PValue<0.05)
dim(lymphoid_df_sel)
# Out:
# [1] 43625    15

# %%
write.csv(lymphoid_df_sel, file='/home/jovyan/projects/kk14_DCM-lymphoid/for_paper/Supplementary_tables/LYMPHOIDS_DEGs_LV.csv')
